# %% [markdown]
# <a href="https://colab.research.google.com/github/edsonlimagithub/bootcampcomputacaocognitiva/blob/master/TokenizacaoSegmentacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install stanza
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 574 kB 14.7 MB/s
# ...
#      |████████████████████████████████| 175 kB 67.4 MB/s
# ...
#      |████████████████████████████████| 4.4 MB 65.0 MB/s
# ...
#      |████████████████████████████████| 596 kB 84.4 MB/s
# ...
#      |████████████████████████████████| 101 kB 14.9 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 70.8 MB/s
# ...
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=c2d6462ae71181a9c338ea96fd5467f2fe881595c87e7984c790f6e628edd3b3
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
import stanza 
nlp = stanza.Pipeline(lang='en', processors='tokenize') 
doc = nlp('This is a test sentence for stanza. This is another sentence.') 
for i, sentence in enumerate(doc.sentences):     
    print(f'====== Sentence {i+1} tokens =======')     
    print(*[f'id: {token.id}\ttext: {token.text}' for token in sentence.tokens], sep='\n')
# Out:
# ...
# 2022-06-24 11:16:00 INFO: Loading these models for language: en (English):
# ...
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# ...
#
# 2022-06-24 11:16:00 INFO: Use device: cpu
# 2022-06-24 11:16:00 INFO: Loading: tokenize
# 2022-06-24 11:16:00 INFO: Done loading processors!
# ====== Sentence 1 tokens =======
# id: (1,)	text: This
# id: (2,)	text: is
# id: (3,)	text: a
# id: (4,)	text: test
# id: (5,)	text: sentence
# id: (6,)	text: for
# id: (7,)	text: stanza
# id: (8,)	text: .
# ====== Sentence 2 tokens =======
# id: (1,)	text: This
# id: (2,)	text: is
# id: (3,)	text: another
# id: (4,)	text: sentence
# id: (5,)	text: .

# %%
print([sentence.text for sentence in doc.sentences])
# Out:
# ['This is a test sentence for stanza.', 'This is another sentence.']

# %%
nlp = stanza.Pipeline(lang='en', processors='tokenize', tokenize_no_ssplit=True)
doc = nlp('This is a sentence.\n\nThis is a second. This is a third.')
for i, sentence in enumerate(doc.sentences):
    print(f'====== Sentence {i+1} tokens =======')
    print(*[f'id: {token.id}\ttext: {token.text}' for token in sentence.tokens], sep='\n')
# Out:
# ...
# 2022-06-24 11:16:56 INFO: Loading these models for language: en (English):
# ...
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# ...
#
# 2022-06-24 11:16:56 INFO: Use device: cpu
# 2022-06-24 11:16:56 INFO: Loading: tokenize
# 2022-06-24 11:16:56 INFO: Done loading processors!
# ====== Sentence 1 tokens =======
# id: (1,)	text: This
# id: (2,)	text: is
# id: (3,)	text: a
# id: (4,)	text: sentence
# id: (5,)	text: .
# ====== Sentence 2 tokens =======
# id: (1,)	text: This
# id: (2,)	text: is
# id: (3,)	text: a
# id: (4,)	text: second
# id: (5,)	text: .
# id: (6,)	text: This
# id: (7,)	text: is
# id: (8,)	text: a
# id: (9,)	text: third
# id: (10,)	text: .

# %%
nlp = stanza.Pipeline(lang='en', processors='tokenize', tokenize_pretokenized=True)
doc = nlp('This is token.ization done my way!\nSentence split, too!')
for i, sentence in enumerate(doc.sentences):
    print(f'====== Sentence {i+1} tokens =======')
    print(*[f'id: {token.id}\ttext: {token.text}' for token in sentence.tokens], sep='\n')
# Out:
# ...
# 2022-06-24 11:18:14 INFO: Loading these models for language: en (English):
# ...
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# ...
#
# 2022-06-24 11:18:14 INFO: Use device: cpu
# 2022-06-24 11:18:14 INFO: Loading: tokenize
# 2022-06-24 11:18:14 INFO: Done loading processors!
# ====== Sentence 1 tokens =======
# id: (1,)	text: This
# id: (2,)	text: is
# id: (3,)	text: token.ization
# id: (4,)	text: done
# id: (5,)	text: my
# id: (6,)	text: way!
# ====== Sentence 2 tokens =======
# id: (1,)	text: Sentence
# id: (2,)	text: split,
# id: (3,)	text: too!

# %%
nlp = stanza.Pipeline(lang='en', processors='tokenize', tokenize_pretokenized=True)
doc = nlp([['This', 'is', 'token.ization', 'done', 'my', 'way!'], ['Sentence', 'split,', 'too!']])
for i, sentence in enumerate(doc.sentences):
    print(f'====== Sentence {i+1} tokens =======')
    print(*[f'id: {token.id}\ttext: {token.text}' for token in sentence.tokens], sep='\n')
# Out:
# ...
# 2022-06-24 11:18:42 INFO: Loading these models for language: en (English):
# ...
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# ...
#
# 2022-06-24 11:18:42 INFO: Use device: cpu
# 2022-06-24 11:18:42 INFO: Loading: tokenize
# 2022-06-24 11:18:42 INFO: Done loading processors!
# ====== Sentence 1 tokens =======
# id: (1,)	text: This
# id: (2,)	text: is
# id: (3,)	text: token.ization
# id: (4,)	text: done
# id: (5,)	text: my
# id: (6,)	text: way!
# ====== Sentence 2 tokens =======
# id: (1,)	text: Sentence
# id: (2,)	text: split,
# id: (3,)	text: too!
